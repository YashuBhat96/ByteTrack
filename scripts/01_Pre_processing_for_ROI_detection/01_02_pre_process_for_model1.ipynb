# %% [markdown]
# ## sampling

# %%
import os
import shutil
import random
from concurrent.futures import ThreadPoolExecutor, as_completed

def sample_and_copy_files_from_subdir(root, subdirs, source_dir, target_dir, num_samples_subdir, num_samples_images):
    sampled_subdirs = random.sample(subdirs, min(num_samples_subdir, len(subdirs)))

    for subdir in sampled_subdirs:
        subdir_path = os.path.join(root, subdir)
        files = os.listdir(subdir_path)
        image_files = [file for file in files if file.lower().endswith(('jpg', 'jpeg', 'png'))]
        xml_files = [file for file in files if file.lower().endswith('xml')]

        # Ensure each image has a corresponding XML file
        image_xml_pairs = [(img, img.replace(os.path.splitext(img)[1], '.xml')) for img in image_files if img.replace(os.path.splitext(img)[1], '.xml') in xml_files]

        # Sample the pairs
        sampled_pairs = random.sample(image_xml_pairs, min(num_samples_images, len(image_xml_pairs)))

        # Create the corresponding target directory
        relative_path = os.path.relpath(subdir_path, source_dir)
        target_subdir = os.path.join(target_dir, relative_path)
        os.makedirs(target_subdir, exist_ok=True)

        # Copy the sampled files
        for img, xml in sampled_pairs:
            shutil.copy(os.path.join(subdir_path, img), os.path.join(target_subdir, img))
            shutil.copy(os.path.join(subdir_path, xml), os.path.join(target_subdir, xml))

def sample_and_copy_files(source_dir, target_dir, num_samples_subdir=10, num_samples_images=50):
    with ThreadPoolExecutor() as executor:
        futures = []
        for root, dirs, _ in os.walk(source_dir):
            if root == source_dir:
                for ps_dir in dirs:
                    ps_path = os.path.join(root, ps_dir)
                    ps_subdirs = [d for d in os.listdir(ps_path) if os.path.isdir(os.path.join(ps_path, d))]
                    futures.append(executor.submit(sample_and_copy_files_from_subdir, ps_path, ps_subdirs, source_dir, target_dir, num_samples_subdir, num_samples_images))

        for future in as_completed(futures):
            future.result()

if __name__ == "__main__":
    source_dir = r"C:\Users\ybr5070\Desktop\all_frames"  # Replace with the path to your source directory
    target_dir = r"C:\Users\ybr5070\Desktop\sampled"  # Replace with the path to your target directory
    sample_and_copy_files(source_dir, target_dir)

# %% [markdown]
# ## split into train, val,test

# %%
import os
import shutil
import random
from concurrent.futures import ThreadPoolExecutor, as_completed

def split_and_copy_folders(base_folder, train_folder, test_folder, val_folder, train_pct=0.7, test_pct=0.15):
    all_subfolders = []
    for root, dirs, _ in os.walk(base_folder):
        if root != base_folder:
            for subdir in dirs:
                all_subfolders.append(os.path.join(root, subdir))

    random.shuffle(all_subfolders)

    total_subfolders = len(all_subfolders)
    train_end = int(total_subfolders * train_pct)
    test_end = train_end + int(total_subfolders * test_pct)

    train_subfolders = all_subfolders[:train_end]
    test_subfolders = all_subfolders[train_end:test_end]
    val_subfolders = all_subfolders[test_end:]

    def copy_subfolders(subfolders, destination):
        for subfolder in subfolders:
            subfolder_name = os.path.basename(subfolder)
            dst_path = os.path.join(destination, subfolder_name)
            try:
                shutil.copytree(subfolder, dst_path)
                print(f"Copied {subfolder_name} to {destination}")
            except Exception as e:
                print(f"Error copying {subfolder_name} to {destination}: {e}")

    with ThreadPoolExecutor() as executor:
        futures = []
        futures.append(executor.submit(copy_subfolders, train_subfolders, train_folder))
        futures.append(executor.submit(copy_subfolders, test_subfolders, test_folder))
        futures.append(executor.submit(copy_subfolders, val_subfolders, val_folder))

        for future in as_completed(futures):
            future.result()

# Example usage
base_folder = r"C:\Users\ybr5070\Desktop\sampled"
train_folder = r"C:\Users\ybr5070\Desktop\split\train"
test_folder = r"C:\Users\ybr5070\Desktop\split\test"
val_folder = r"C:\Users\ybr5070\Desktop\split\val"

split_and_copy_folders(base_folder, train_folder, test_folder, val_folder)

# %% [markdown]
# # Transformations on train set

# %%
import cv2
import numpy as np
import xml.etree.ElementTree as ET
import os
import glob
import logging
from concurrent.futures import ThreadPoolExecutor


# Function to read the image frame and the corresponding XML file
def read_frame_and_xml(frame_path, xml_path):
    frame = cv2.imread(frame_path)
    tree = ET.parse(xml_path)
    root = tree.getroot()
    return frame, tree, root

# Image transformation functions
def y_reflection(frame):
    return cv2.flip(frame, 1)

def gaussian_blur(frame, kernel_size=(5, 5), sigmaX=0):
    return cv2.GaussianBlur(frame, kernel_size, sigmaX)

def adjust_brightness(frame, value=30):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)
    lim = 255 - value
    v[v > lim] = 255
    v[v <= lim] += value
    final_hsv = cv2.merge((h, s, v))
    frame = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return frame

def change_orientation_to_portrait(frame):
    if frame.shape[1] > frame.shape[0]:
        frame = cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)
    return frame

def crop_and_rotate(frame, angle=10):
    height, width = frame.shape[:2]
    center = (width // 2, height // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)

    abs_cos = abs(M[0, 0])
    abs_sin = abs(M[0, 1])

    bound_w = int(height * abs_sin + width * abs_cos)
    bound_h = int(height * abs_cos + width * abs_sin)

    M[0, 2] += bound_w / 2 - center[0]
    M[1, 2] += bound_h / 2 - center[1]

    rotated = cv2.warpAffine(frame, M, (bound_w, bound_h))
    return rotated

# XML transformation functions
def update_xml_for_y_reflection(root, image_width):
    for obj in root.iter('object'):
        bndbox = obj.find('bndbox')
        xmin = image_width - int(bndbox.find('xmax').text)
        xmax = image_width - int(bndbox.find('xmin').text)
        bndbox.find('xmin').text = str(xmin)
        bndbox.find('xmax').text = str(xmax)
    return root

def rotate_point(x, y, M):
    point = np.array([[x], [y], [1]])
    transformed_point = np.dot(M, point)
    return int(transformed_point[0]), int(transformed_point[1])

def update_xml_for_portrait(root, original_width, original_height):
    for obj in root.iter('object'):
        bndbox = obj.find('bndbox')
        xmin = int(bndbox.find('xmin').text)
        ymin = int(bndbox.find('ymin').text)
        xmax = int(bndbox.find('xmax').text)
        ymax = int(bndbox.find('ymax').text)

        new_xmin = original_height - ymax
        new_ymin = xmin
        new_xmax = original_height - ymin
        new_ymax = xmax

        bndbox.find('xmin').text = str(new_xmin)
        bndbox.find('ymin').text = str(new_ymin)
        bndbox.find('xmax').text = str(new_xmax)
        bndbox.find('ymax').text = str(new_ymax)

    return root

def update_xml_for_rotation(root, angle, image_width, image_height):
    center_x, center_y = image_width // 2, image_height // 2
    M = cv2.getRotationMatrix2D((center_x, center_y), angle, 1.0)

    abs_cos = abs(M[0, 0])
    abs_sin = abs(M[0, 1])
    bound_w = int(image_height * abs_sin + image_width * abs_cos)
    bound_h = int(image_height * abs_cos + image_width * abs_sin)

    M[0, 2] += bound_w / 2 - center_x
    M[1, 2] += bound_h / 2 - center_y

    for obj in root.iter('object'):
        bndbox = obj.find('bndbox')
        xmin = int(bndbox.find('xmin').text)
        ymin = int(bndbox.find('ymin').text)
        xmax = int(bndbox.find('xmax').text)
        ymax = int(bndbox.find('ymax').text)

        rotated_corners = [rotate_point(x, y, M) for x, y in [(xmin, ymin), (xmax, ymin), (xmax, ymax), (xmin, ymax)]]

        xs = [x for x, _ in rotated_corners]
        ys = [y for _, y in rotated_corners]
        new_xmin, new_xmax = min(xs), max(xs)
        new_ymin, new_ymax = min(ys), max(ys)

        bndbox.find('xmin').text = str(new_xmin)
        bndbox.find('ymin').text = str(new_ymin)
        bndbox.find('xmax').text = str(new_xmax)
        bndbox.find('ymax').text = str(new_ymax)

    return root

def process_frame_and_xml(frame_path, xml_path, output_path):
    filename = os.path.splitext(os.path.basename(frame_path))[0]
    transformations = {
        'y_reflected': (y_reflection, update_xml_for_y_reflection),
        'blurred': (gaussian_blur, None),
        'brightness_adjusted': (adjust_brightness, None),
        'portrait': (change_orientation_to_portrait, update_xml_for_portrait),
        'rotated': (lambda f: crop_and_rotate(f, angle=10), update_xml_for_rotation)
    }

    for trans_name, (trans_func, xml_func) in transformations.items():
        try:
            original_frame, tree, root = read_frame_and_xml(frame_path, xml_path)
            transformed_frame = trans_func(original_frame)
            new_root = ET.ElementTree(root).getroot() if xml_func else root

            if xml_func:
                if trans_name == 'rotated':
                    new_root = xml_func(new_root, 10, original_frame.shape[1], original_frame.shape[0])
                elif trans_name == 'portrait':
                    new_root = xml_func(new_root, original_frame.shape[1], original_frame.shape[0])
                elif trans_name == 'y_reflected':
                    new_root = xml_func(new_root, original_frame.shape[1])

            new_tree = ET.ElementTree(new_root)
            new_tree.write(os.path.join(output_path, f'{filename}_{trans_name}.xml'))
            cv2.imwrite(os.path.join(output_path, f'{filename}_{trans_name}.jpg'), transformed_frame)
            print(f"Processed {filename} with transformation {trans_name}")
        except Exception as e:
            print(f"Error processing {filename} with transformation {trans_name}: {e}")

def process_directory(input_dir, output_dir):
    with ThreadPoolExecutor(max_workers=os.cpu_count()) as executor:
        futures = []
        for subject_folder in os.listdir(input_dir):
            subject_path = os.path.join(input_dir, subject_folder)
            if os.path.isdir(subject_path):
                output_subject_path = os.path.join(output_dir, subject_folder)
                os.makedirs(output_subject_path, exist_ok=True)

                frame_paths = glob.glob(os.path.join(subject_path, '*.jpg'))
                xml_paths = {os.path.splitext(os.path.basename(p))[0]: p for p in glob.glob(os.path.join(subject_path, '*.xml'))}

                for frame_path in frame_paths:
                    frame_basename = os.path.splitext(os.path.basename(frame_path))[0]
                    xml_path = xml_paths.get(frame_basename)
                    if xml_path:
                        future = executor.submit(process_frame_and_xml, frame_path, xml_path, output_subject_path)
                        futures.append(future)
                    else:
                        print(f"Skipping frame {frame_basename} due to missing XML file")

        for future in futures:
            future.result()

    print("All directories processed!")

# Example usage
train_dir =r"C:\Users\ybr5070\Desktop\split\train"  # Replace with your actual train directory
output_dir = r"C:\Users\ybr5070\Desktop\split\train_trans" # Replace with your actual output directory

process_directory(train_dir, output_dir)
# Out:
# Processed frame10147 with transformation y_reflectedProcessed frame10012 with transformation y_reflected
# Processed frame1408 with transformation y_reflected
#
# Processed frame1671 with transformation y_reflected
# Processed frame231 with transformation y_reflected
# Processed frame2465 with transformation y_reflected
# Processed frame2284 with transformation y_reflected
# Processed frame2427 with transformation y_reflected
# Processed frame1963 with transformation y_reflected
# Processed frame2097 with transformation y_reflected
# Processed frame2812 with transformation y_reflected
# Processed frame4904 with transformation y_reflected
# Processed frame4283 with transformation y_reflected
# Processed frame2532 with transformation y_reflected
# Processed frame3450 with transformation y_reflected
# Processed frame4034 with transformation y_reflected
# Processed frame3260 with transformation y_reflected
# Processed frame4597 with transformation y_reflected
# Processed frame2827 with transformation y_reflected
# Processed frame381 with transformation y_reflected
# Processed frame231 with transformation blurred
# Processed frame10012 with transformation blurred
# Processed frame10147 with transformation blurred
# Processed frame1671 with transformation blurred
# Processed frame1408 with transformation blurred
# Processed frame2427 with transformation blurred
# Processed frame2284 with transformation blurred
# Processed frame4904 with transformation blurred
# Processed frame2097 with transformation blurred
# Processed frame1963 with transformation blurred
# Processed frame2465 with transformation blurred
# Processed frame4283 with transformation blurred
# Processed frame3450 with transformation blurred
# Processed frame3260 with transformation blurred
# Processed frame2812 with transformation blurred
# Processed frame4034 with transformation blurred
# Processed frame2532 with transformation blurred
# Processed frame4597 with transformation blurred
# Processed frame2827 with transformation blurred
# Processed frame381 with transformation blurred
# Processed frame231 with transformation brightness_adjusted
# Processed frame1671 with transformation brightness_adjusted
# Processed frame10012 with transformation brightness_adjusted
# Processed frame10147 with transformation brightness_adjusted
# Processed frame1408 with transformation brightness_adjusted
# Processed frame2284 with transformation brightness_adjusted
# Processed frame1963 with transformation brightness_adjusted
# Processed frame2097 with transformation brightness_adjusted
# Processed frame4904 with transformation brightness_adjusted
# Processed frame2427 with transformation brightness_adjusted
# Processed frame4283 with transformation brightness_adjusted
# Processed frame231 with transformation portrait
# Processed frame4034 with transformation brightness_adjusted
# Processed frame1671 with transformation portrait
# Processed frame10012 with transformation portrait
# Processed frame3450 with transformation brightness_adjusted
# Processed frame10147 with transformation portrait
# Processed frame381 with transformation brightness_adjusted
# Processed frame4597 with transformation brightness_adjusted
# Processed frame2812 with transformation brightness_adjusted
# Processed frame2465 with transformation brightness_adjusted
# Processed frame3260 with transformation brightness_adjusted
# Processed frame1408 with transformation portrait
# Processed frame1963 with transformation portrait
# Processed frame2827 with transformation brightness_adjusted
# Processed frame4904 with transformation portrait
# Processed frame2097 with transformation portrait
# Processed frame2284 with transformation portrait
# Processed frame2532 with transformation brightness_adjusted
# Processed frame4283 with transformation portrait
# Processed frame4034 with transformation portrait
# Processed frame2427 with transformation portrait
# Processed frame381 with transformation portrait
# Processed frame1671 with transformation rotated
# Processed frame231 with transformation rotated
# Processed frame3450 with transformation portrait
# Processed frame4597 with transformation portrait
# Processed frame2812 with transformation portrait
# Processed frame10012 with transformation rotated
# Processed frame2465 with transformation portrait
# Processed frame3260 with transformation portrait
# Processed frame10147 with transformation rotated
# Processed frame1408 with transformation rotated
# Processed frame2827 with transformation portrait
# Processed frame2532 with transformation portrait
# Processed frame2284 with transformation rotated
# Processed frame4970 with transformation y_reflected
# Processed frame4904 with transformation rotated
# Processed frame4283 with transformation rotated
# Processed frame2097 with transformation rotated
# Processed frame1963 with transformation rotated
# Processed frame2427 with transformation rotated
# Processed frame5067 with transformation y_reflected
# Processed frame4034 with transformation rotated
# Processed frame5470 with transformation y_reflected
# Processed frame381 with transformation rotated
# Processed frame5747 with transformation y_reflected
# Processed frame5561 with transformation y_reflected
# Processed frame4597 with transformation rotated
# Processed frame5818 with transformation y_reflected
# Processed frame6188 with transformation y_reflected
# Processed frame5849 with transformation y_reflected
# Processed frame2465 with transformation rotated
# Processed frame4970 with transformation blurred
# Processed frame6311 with transformation y_reflected
# Processed frame3450 with transformation rotatedProcessed frame2812 with transformation rotated
#
# Processed frame3260 with transformation rotated
# Processed frame2827 with transformation rotated
# Processed frame5470 with transformation blurred
# Processed frame2532 with transformation rotated
# Processed frame5818 with transformation blurred
# Processed frame5067 with transformation blurred
# Processed frame6660 with transformation y_reflected
# Processed frame6188 with transformation blurred
# Processed frame6807 with transformation y_reflected
# Processed frame7140 with transformation y_reflected
# Processed frame6311 with transformation blurred
# Processed frame5849 with transformation blurred
# Processed frame667 with transformation y_reflected
# Processed frame7044 with transformation y_reflected
# Processed frame7338 with transformation y_reflected
# Processed frame6109 with transformation y_reflected
# Processed frame7313 with transformation y_reflected
# Processed frame6660 with transformation blurred
# Processed frame5470 with transformation brightness_adjusted
# Processed frame5818 with transformation brightness_adjusted
# Processed frame5067 with transformation brightness_adjusted
# Processed frame6268 with transformation y_reflected
# Processed frame5747 with transformation blurred
# Processed frame6519 with transformation y_reflected
# Processed frame7140 with transformation blurred
# Processed frame6807 with transformation blurredProcessed frame6643 with transformation y_reflected
#
# Processed frame5561 with transformation blurred
# Processed frame667 with transformation blurred
# Processed frame7044 with transformation blurred
# Processed frame7338 with transformation blurred
# Processed frame6188 with transformation brightness_adjusted
# Processed frame7313 with transformation blurred
# Processed frame6311 with transformation brightness_adjusted
# Processed frame5849 with transformation brightness_adjusted
# Processed frame6109 with transformation blurred
# Processed frame5818 with transformation portrait
# Processed frame5067 with transformation portrait
# Processed frame5470 with transformation portrait
# Processed frame4970 with transformation brightness_adjusted
# Processed frame6660 with transformation brightness_adjusted
# Processed frame6268 with transformation blurred
# Processed frame6519 with transformation blurred
# Processed frame6643 with transformation blurred
# Processed frame5747 with transformation brightness_adjusted
# Processed frame6188 with transformation portrait
# Processed frame6311 with transformation portraitProcessed frame5561 with transformation brightness_adjusted
#
# Processed frame5849 with transformation portrait
# Processed frame7140 with transformation brightness_adjusted
# Processed frame6660 with transformation portrait
# Processed frame6807 with transformation brightness_adjusted
# Processed frame5818 with transformation rotated
# Processed frame4970 with transformation portrait
# Processed frame6109 with transformation brightness_adjusted
# Processed frame5067 with transformation rotated
# Processed frame5747 with transformation portrait
# Processed frame667 with transformation brightness_adjusted
# Processed frame7044 with transformation brightness_adjusted
# Processed frame7313 with transformation brightness_adjusted
# Processed frame6268 with transformation brightness_adjusted
# Processed frame7338 with transformation brightness_adjusted
# Processed frame5470 with transformation rotated
# Processed frame6519 with transformation brightness_adjusted
# Processed frame6188 with transformation rotated
# Processed frame5561 with transformation portrait
# Processed frame6311 with transformation rotated
# Processed frame6643 with transformation brightness_adjusted
# Processed frame7421 with transformation y_reflected
# Processed frame7140 with transformation portrait
# Processed frame7923 with transformation y_reflected
# Processed frame6807 with transformation portrait
# Processed frame5849 with transformation rotated
# Processed frame6109 with transformation portrait
# Processed frame6660 with transformation rotated
# Processed frame6268 with transformation portrait
# Processed frame7313 with transformation portrait
# Processed frame667 with transformation portrait
# Processed frame7960 with transformation y_reflected
# Processed frame7338 with transformation portrait
# Processed frame6519 with transformation portrait
# Processed frame7044 with transformation portrait
# Processed frame8247 with transformation y_reflected
# Processed frame7936 with transformation y_reflected
# Processed frame7421 with transformation blurred
# Processed frame4970 with transformation rotated
# Processed frame7923 with transformation blurred
# Processed frame6643 with transformation portrait
# Processed frame8909 with transformation y_reflected
# Processed frame5747 with transformation rotated
# Processed frame5561 with transformation rotated
# Processed frame9021 with transformation y_reflected
# Processed frame7960 with transformation blurred
# Processed frame8247 with transformation blurred
# Processed frame7936 with transformation blurred
# Processed frame7140 with transformation rotated
# Processed frame6807 with transformation rotated
# Processed frame7421 with transformation brightness_adjusted
# Processed frame7313 with transformation rotated
# Processed frame667 with transformation rotated
# Processed frame7338 with transformation rotated
# Processed frame9021 with transformation blurred
# Processed frame7044 with transformation rotated
# Processed frame8909 with transformation blurred
# Processed frame7923 with transformation brightness_adjusted
# Processed frame1031 with transformation y_reflected
# Processed frame7960 with transformation brightness_adjusted
# Processed frame1044 with transformation y_reflected
# Processed frame1079 with transformation y_reflected
# Processed frame11 with transformation y_reflected
# Processed frame8247 with transformation brightness_adjusted
# Processed frame1114 with transformation y_reflected
# Processed frame1101 with transformation y_reflected
# Processed frame9383 with transformation y_reflected
# Processed frame6109 with transformation rotated
# Processed frame7421 with transformation portrait
# Processed frame7936 with transformation brightness_adjusted
# Processed frame7923 with transformation portrait
# Processed frame9021 with transformation brightness_adjusted
# Processed frame1044 with transformation blurred
# Processed frame1031 with transformation blurred
# Processed frame8909 with transformation brightness_adjusted
# Processed frame7960 with transformation portrait
# Processed frame6268 with transformation rotated
# Processed frame1114 with transformation blurred
# Processed frame1079 with transformation blurred
# Processed frame1101 with transformation blurred
# Processed frame11 with transformation blurred
# Processed frame6519 with transformation rotated
# Processed frame8247 with transformation portrait
# Processed frame9639 with transformation y_reflected
# Processed frame9952 with transformation y_reflected
# Processed frame7936 with transformation portrait
# Processed frame9021 with transformation portrait
# Processed frame8909 with transformation portrait
# Processed frame7923 with transformation rotated
# Processed frame1044 with transformation brightness_adjusted
# Processed frame1031 with transformation brightness_adjusted
# Processed frame7960 with transformation rotated
# Processed frame7421 with transformation rotated
# Processed frame6643 with transformation rotated
# Processed frame9383 with transformation blurred
# Processed frame1114 with transformation brightness_adjusted
# Processed frame1101 with transformation brightness_adjusted
# Processed frame7936 with transformation rotated
# Processed frame1206 with transformation y_reflected
# Processed frame11 with transformation brightness_adjustedProcessed frame1079 with transformation brightness_adjusted
#
# Processed frame1219 with transformation y_reflected
# Processed frame9639 with transformation blurred
# Processed frame126 with transformation y_reflected
# Processed frame8247 with transformation rotated
# Processed frame9952 with transformation blurred
# Processed frame1044 with transformation portrait
# Processed frame1031 with transformation portrait
# Processed frame1371 with transformation y_reflected
# Processed frame1505 with transformation y_reflected
# Processed frame1405 with transformation y_reflected
# Processed frame9021 with transformation rotated
# Processed frame1114 with transformation portrait
# Processed frame8909 with transformation rotated
# Processed frame1547 with transformation y_reflected
# Processed frame1101 with transformation portrait
# Processed frame1079 with transformation portrait
# Processed frame11 with transformation portrait
# Processed frame1525 with transformation y_reflected
# Processed frame1549 with transformation y_reflected
# Processed frame1505 with transformation blurred
# Processed frame1371 with transformation blurred
# Processed frame1405 with transformation blurred
# Processed frame1560 with transformation y_reflected
# Processed frame1044 with transformation rotated
# Processed frame1547 with transformation blurred
# Processed frame1219 with transformation blurred
# Processed frame159 with transformation y_reflected
# Processed frame1206 with transformation blurred
# Processed frame126 with transformation blurred
# Processed frame1031 with transformation rotated
# Processed frame1549 with transformation blurred
# Processed frame9383 with transformation brightness_adjusted
# Processed frame1114 with transformation rotated
# Processed frame9952 with transformation brightness_adjusted
# Processed frame9639 with transformation brightness_adjusted
# Processed frame1101 with transformation rotated
# Processed frame1079 with transformation rotated
# Processed frame1560 with transformation blurred
# Processed frame1505 with transformation brightness_adjusted
# Processed frame11 with transformation rotated
# Processed frame1371 with transformation brightness_adjusted
# Processed frame1525 with transformation blurred
# Processed frame1644 with transformation y_reflected
# Processed frame159 with transformation blurred
# Processed frame1405 with transformation brightness_adjusted
# Processed frame1650 with transformation y_reflected
# Processed frame1547 with transformation brightness_adjusted
# Processed frame1669 with transformation y_reflected
# Processed frame1682 with transformation y_reflected
# Processed frame1700 with transformation y_reflected
# Processed frame1505 with transformation portrait
# Processed frame1549 with transformation brightness_adjusted
# Processed frame1644 with transformation blurred
# Processed frame1703 with transformation y_reflected
# Processed frame1371 with transformation portrait
# Processed frame1650 with transformation blurred
# Processed frame1560 with transformation brightness_adjusted
# Processed frame1405 with transformation portrait
# Processed frame9952 with transformation portrait
# Processed frame126 with transformation brightness_adjusted
# Processed frame9383 with transformation portrait
# Processed frame159 with transformation brightness_adjusted
# Processed frame1547 with transformation portrait
# Processed frame1219 with transformation brightness_adjusted
# Processed frame1669 with transformation blurred
# Processed frame9639 with transformation portrait
# Processed frame1206 with transformation brightness_adjusted
# Processed frame1682 with transformation blurred
# Processed frame1700 with transformation blurred
# Processed frame1549 with transformation portrait
# Processed frame1525 with transformation brightness_adjusted
# Processed frame1703 with transformation blurred
# Processed frame1560 with transformation portrait
# Processed frame1371 with transformation rotated
# Processed frame159 with transformation portraitProcessed frame1505 with transformation rotated
#
# Processed frame1644 with transformation brightness_adjusted
# Processed frame126 with transformation portrait
# Processed frame1650 with transformation brightness_adjusted
# Processed frame1405 with transformation rotated
# Processed frame1219 with transformation portrait
# Processed frame1669 with transformation brightness_adjusted
# Processed frame1206 with transformation portrait
# Processed frame1774 with transformation y_reflected
# Processed frame1547 with transformation rotated
# Processed frame1785 with transformation y_reflected
# Processed frame1525 with transformation portrait
# Processed frame1549 with transformation rotated
# Processed frame9383 with transformation rotated
# Processed frame9952 with transformation rotated
# Processed frame1682 with transformation brightness_adjusted
# Processed frame1700 with transformation brightness_adjusted
# Processed frame1644 with transformation portrait
# Processed frame9639 with transformation rotated
# Processed frame1821 with transformation y_reflected
# Processed frame1560 with transformation rotated
# Processed frame1703 with transformation brightness_adjusted
# Processed frame1650 with transformation portrait
# Processed frame1852 with transformation y_reflected
# Processed frame159 with transformation rotated
# Processed frame1669 with transformation portrait
# Processed frame1774 with transformation blurred
# Processed frame191 with transformation y_reflected
# Processed frame1219 with transformation rotated
# Processed frame1785 with transformation blurred
# Processed frame1682 with transformation portrait
# Processed frame126 with transformation rotated
# Processed frame1700 with transformation portrait
# Processed frame2004 with transformation y_reflected
# Processed frame1821 with transformation blurred
# Processed frame1925 with transformation y_reflected
# Processed frame1644 with transformation rotated
# Processed frame1703 with transformation portrait
# Processed frame194 with transformation y_reflected
# Processed frame1942 with transformation y_reflected
# Processed frame1206 with transformation rotated
# Processed frame1852 with transformation blurred
# Processed frame2302 with transformation y_reflected
# Processed frame191 with transformation blurred
# Processed frame1774 with transformation brightness_adjusted
# Processed frame1650 with transformation rotated
# Processed frame2004 with transformation blurred
# Processed frame1669 with transformation rotated
# Processed frame1785 with transformation brightness_adjusted
# Processed frame1525 with transformation rotated
# Processed frame3501 with transformation y_reflected
# Processed frame2900 with transformation y_reflected
# Processed frame1821 with transformation brightness_adjusted
# Processed frame3468 with transformation y_reflected
# Processed frame2302 with transformation blurred
# Processed frame1925 with transformation blurred
# Processed frame1700 with transformation rotated
# Processed frame1682 with transformation rotated
# Processed frame194 with transformation blurred
# Processed frame3805 with transformation y_reflected
# Processed frame1942 with transformation blurred
# Processed frame1852 with transformation brightness_adjusted
# Processed frame1774 with transformation portrait
# Processed frame1703 with transformation rotated
# Processed frame401 with transformation y_reflected
# Processed frame191 with transformation brightness_adjusted
# Processed frame1785 with transformation portrait
# Processed frame4102 with transformation y_reflected
# Processed frame1821 with transformation portrait
# Processed frame3501 with transformation blurred
# Processed frame2004 with transformation brightness_adjusted
# Processed frame4153 with transformation y_reflected
# Processed frame4850 with transformation y_reflected
# Processed frame4953 with transformation y_reflected
# Processed frame2900 with transformation blurred
# Processed frame1852 with transformation portrait
# Processed frame2302 with transformation brightness_adjusted
# Processed frame5251 with transformation y_reflected
# Processed frame3468 with transformation blurred
# Processed frame3805 with transformation blurred
# Processed frame401 with transformation blurred
# Processed frame4102 with transformation blurred
# Processed frame191 with transformation portrait
# Processed frame1774 with transformation rotated
# Processed frame194 with transformation brightness_adjusted
# Processed frame2004 with transformation portrait
# Processed frame1925 with transformation brightness_adjusted
# Processed frame4850 with transformation blurred
# Processed frame1942 with transformation brightness_adjusted
# Processed frame4953 with transformation blurred
# Processed frame2302 with transformation portrait
# Processed frame3501 with transformation brightness_adjusted
# Processed frame1821 with transformation rotated
# Processed frame1785 with transformation rotated
# Processed frame5251 with transformation blurred
# Processed frame4153 with transformation blurred
# Processed frame1852 with transformation rotated
# Processed frame5252 with transformation y_reflected
# Processed frame3805 with transformation brightness_adjusted
# Processed frame191 with transformation rotated
# Processed frame2900 with transformation brightness_adjusted
# Processed frame194 with transformation portrait
# Processed frame401 with transformation brightness_adjusted
# Processed frame3468 with transformation brightness_adjusted
# Processed frame1925 with transformation portrait
# Processed frame4102 with transformation brightness_adjusted
# Processed frame2004 with transformation rotated
# Processed frame5803 with transformation y_reflected
# Processed frame3501 with transformation portrait
# Processed frame6255 with transformation y_reflected
# Processed frame1942 with transformation portrait
# Processed frame4850 with transformation brightness_adjusted
# Processed frame2302 with transformation rotated
# Processed frame7053 with transformation y_reflected
# Processed frame4953 with transformation brightness_adjusted
# Processed frame5252 with transformation blurred
# Processed frame5251 with transformation brightness_adjusted
# Processed frame4153 with transformation brightness_adjusted
# Processed frame8652 with transformation y_reflected
# Processed frame401 with transformation portrait
# Processed frame3805 with transformation portrait
# Processed frame4102 with transformation portrait
# Processed frame8701 with transformation y_reflected
# Processed frame3468 with transformation portrait
# Processed frame5803 with transformation blurred
# Processed frame2900 with transformation portrait
# Processed frame8704 with transformation y_reflected
# Processed frame6255 with transformation blurred
# Processed frame194 with transformation rotated
# Processed frame7053 with transformation blurred
# Processed frame4850 with transformation portrait
# Processed frame3501 with transformation rotated
# Processed frame4953 with transformation portrait
# Processed frame5251 with transformation portrait
# Processed frame1942 with transformation rotated
# Processed frame1925 with transformation rotated
# Processed frame4153 with transformation portrait
# Processed frame8652 with transformation blurred
# Processed frame8701 with transformation blurred
# Processed frame5252 with transformation brightness_adjusted
# Processed frame8704 with transformation blurred
# Processed frame1055 with transformation y_reflected
# Processed frame1392 with transformation y_reflected
# Processed frame3805 with transformation rotated
# Processed frame3468 with transformation rotated
# Processed frame401 with transformation rotated
# Processed frame2900 with transformation rotated
# Processed frame5803 with transformation brightness_adjusted
# Processed frame4102 with transformation rotated
# Processed frame1501 with transformation y_reflected
# Processed frame1545 with transformation y_reflected
# Processed frame6255 with transformation brightness_adjusted
# Processed frame7053 with transformation brightness_adjusted
# Processed frame4850 with transformation rotated
# Processed frame5252 with transformation portrait
# Processed frame1055 with transformation blurred
# Processed frame4953 with transformation rotated
# Processed frame1778 with transformation y_reflected
# Processed frame8652 with transformation brightness_adjusted
# Processed frame1791 with transformation y_reflected
# Processed frame5251 with transformation rotated
# Processed frame1392 with transformation blurred
# Processed frame8701 with transformation brightness_adjusted
# Processed frame2343 with transformation y_reflected
# Processed frame4153 with transformation rotated
# Processed frame5803 with transformation portrait
# Processed frame8704 with transformation brightness_adjusted
# Processed frame1501 with transformation blurred
# Processed frame1921 with transformation y_reflected
# Processed frame1545 with transformation blurred
# Processed frame2480 with transformation y_reflected
# Processed frame6255 with transformation portrait
# Processed frame7053 with transformation portrait
# Processed frame2593 with transformation y_reflected
# Processed frame5252 with transformation rotated
# Processed frame1778 with transformation blurred
# Processed frame1791 with transformation blurred
# Processed frame2606 with transformation y_reflected
# Processed frame1055 with transformation brightness_adjusted
# Processed frame3187 with transformation y_reflected
# Processed frame8701 with transformation portrait
# Processed frame2343 with transformation blurred
# Processed frame8652 with transformation portrait
# Processed frame3080 with transformation y_reflected
# Processed frame1921 with transformation blurred
# Processed frame8704 with transformation portrait
# Processed frame2480 with transformation blurred
# Processed frame1545 with transformation brightness_adjusted
# Processed frame1501 with transformation brightness_adjusted
# Processed frame5803 with transformation rotated
# Processed frame2593 with transformation blurred
# Processed frame1392 with transformation brightness_adjusted
# Processed frame3317 with transformation y_reflected
# Processed frame1055 with transformation portrait
# Processed frame3187 with transformation blurred
# Processed frame1778 with transformation brightness_adjusted
# Processed frame7053 with transformation rotated
# Processed frame2606 with transformation blurred
# Processed frame1791 with transformation brightness_adjusted
# Processed frame2343 with transformation brightness_adjusted
# Processed frame6255 with transformation rotated
# Processed frame1545 with transformation portrait
# Processed frame3080 with transformation blurred
# Processed frame1501 with transformation portrait
# Processed frame8701 with transformation rotated
# Processed frame3459 with transformation y_reflected
# Processed frame8652 with transformation rotated
# Processed frame1921 with transformation brightness_adjusted
# Processed frame1392 with transformation portrait
# Processed frame8704 with transformation rotated
# Processed frame3317 with transformation blurred
# Processed frame1778 with transformation portrait
# Processed frame1055 with transformation rotated
# Processed frame2343 with transformation portrait
# Processed frame3486 with transformation y_reflected
# Processed frame2480 with transformation brightness_adjusted
# Processed frame1791 with transformation portrait
# Processed frame3187 with transformation brightness_adjusted
# Processed frame3526 with transformation y_reflected
# Processed frame3573 with transformation y_reflected
# Processed frame3613 with transformation y_reflected
# Processed frame1501 with transformation rotated
# Processed frame3459 with transformation blurred
# Processed frame2593 with transformation brightness_adjusted
# Processed frame1545 with transformation rotated
# Processed frame365 with transformation y_reflected
# Processed frame3922 with transformation y_reflected
# Processed frame1921 with transformation portrait
# Processed frame2606 with transformation brightness_adjusted
# Processed frame3080 with transformation brightness_adjusted
# Processed frame1778 with transformation rotated
# Processed frame3486 with transformation blurred
# Processed frame3317 with transformation brightness_adjusted
# Processed frame3526 with transformation blurred
# Processed frame3187 with transformation portrait
# Processed frame2480 with transformation portrait
# Processed frame3573 with transformation blurred
# Processed frame3613 with transformation blurred
# Processed frame4238 with transformation y_reflected
# Processed frame1791 with transformation rotated
# Processed frame2343 with transformation rotated
# Processed frame4256 with transformation y_reflected
# Processed frame1392 with transformation rotated
# Processed frame365 with transformation blurred
# Processed frame3922 with transformation blurred
# Processed frame2593 with transformation portrait
# Processed frame3459 with transformation brightness_adjusted
# Processed frame4645 with transformation y_reflected
# Processed frame3317 with transformation portrait
# Processed frame3080 with transformation portrait
# Processed frame2606 with transformation portrait
# Processed frame3486 with transformation brightness_adjusted
# Processed frame4653 with transformation y_reflected
# Processed frame4694 with transformation y_reflected
# Processed frame3526 with transformation brightness_adjusted
# Processed frame4238 with transformation blurred
# Processed frame3187 with transformation rotated
# Processed frame4256 with transformation blurred
# Processed frame3459 with transformation portrait
# Processed frame3613 with transformation brightness_adjusted
# Processed frame4645 with transformation blurred
# Processed frame1921 with transformation rotated
# Processed frame3573 with transformation brightness_adjusted
# Processed frame3922 with transformation brightness_adjusted
# Processed frame4857 with transformation y_reflected
# Processed frame365 with transformation brightness_adjusted
# Processed frame3486 with transformation portrait
# Processed frame2480 with transformation rotated
# Processed frame4694 with transformation blurred
# Processed frame3526 with transformation portrait
# Processed frame3317 with transformation rotated
# Processed frame4653 with transformation blurred
# Processed frame5010 with transformation y_reflected
# Processed frame2593 with transformation rotated
# Processed frame3613 with transformation portrait
# Processed frame4238 with transformation brightness_adjusted
# Processed frame3573 with transformation portrait
# Processed frame4256 with transformation brightness_adjusted
# Processed frame3922 with transformation portrait
# Processed frame3080 with transformation rotated
# Processed frame365 with transformation portrait
# Processed frame2606 with transformation rotated
# Processed frame5015 with transformation y_reflected
# Processed frame4645 with transformation brightness_adjusted
# Processed frame4857 with transformation blurred
# Processed frame3459 with transformation rotated
# Processed frame5103 with transformation y_reflected
# Processed frame5268 with transformation y_reflected
# Processed frame3486 with transformation rotated
# Processed frame4694 with transformation brightness_adjusted
# Processed frame3526 with transformation rotated
# Processed frame4238 with transformation portrait
# Processed frame5010 with transformation blurred
# Processed frame3613 with transformation rotated
# Processed frame4256 with transformation portrait
# Processed frame4653 with transformation brightness_adjusted
# Processed frame3573 with transformation rotated
# Processed frame5968 with transformation y_reflected
# Processed frame5345 with transformation y_reflected
# Processed frame365 with transformation rotated
# Processed frame4645 with transformation portrait
# Processed frame5787 with transformation y_reflected
# Processed frame5015 with transformation blurred
# Processed frame5838 with transformation y_reflected
# Processed frame5268 with transformation blurred
# Processed frame6208 with transformation y_reflected
# Processed frame6248 with transformation y_reflected
# Processed frame3922 with transformation rotated
# Processed frame4694 with transformation portrait
# Processed frame5103 with transformation blurred
# Processed frame6354 with transformation y_reflected
# Processed frame4653 with transformation portrait
# Processed frame637 with transformation y_reflected
# Processed frame5968 with transformation blurred
# Processed frame6807 with transformation y_reflected
# Processed frame5010 with transformation brightness_adjusted
# Processed frame4857 with transformation brightness_adjusted
# Processed frame6248 with transformation blurred
# Processed frame4238 with transformation rotated
# Processed frame6208 with transformation blurred
# Processed frame5345 with transformation blurred
# Processed frame4256 with transformation rotated
# Processed frame6354 with transformation blurred
# Processed frame5268 with transformation brightness_adjusted
# Processed frame5838 with transformation blurred
# Processed frame637 with transformation blurred
# Processed frame7 with transformation y_reflected
# Processed frame5787 with transformation blurred
# Processed frame6807 with transformation blurred
# Processed frame4645 with transformation rotated
# Processed frame4694 with transformation rotated
# Processed frame5968 with transformation brightness_adjusted
# Processed frame5010 with transformation portrait
# Processed frame4653 with transformation rotated
# Processed frame5268 with transformation portrait
# Processed frame5015 with transformation brightness_adjusted
# Processed frame6248 with transformation brightness_adjusted
# Processed frame4857 with transformation portrait
# Processed frame7551 with transformation y_reflected
# Processed frame5103 with transformation brightness_adjusted
# Processed frame7632 with transformation y_reflected
# Processed frame6208 with transformation brightness_adjusted
# Processed frame6354 with transformation brightness_adjusted
# Processed frame7 with transformation blurred
# Processed frame637 with transformation brightness_adjusted
# Processed frame6807 with transformation brightness_adjusted
# Processed frame5968 with transformation portrait
# Processed frame7674 with transformation y_reflected
# Processed frame7679 with transformation y_reflected
# Processed frame6248 with transformation portrait
# Processed frame5345 with transformation brightness_adjusted
# Processed frame5787 with transformation brightness_adjusted
# Processed frame777 with transformation y_reflected
# Processed frame6208 with transformation portrait
# Processed frame5010 with transformation rotated
# Processed frame7551 with transformation blurred
# Processed frame5015 with transformation portrait
# Processed frame6354 with transformation portrait
# Processed frame5838 with transformation brightness_adjusted
# Processed frame637 with transformation portrait
# Processed frame5268 with transformation rotated
# Processed frame7632 with transformation blurred
# Processed frame6807 with transformation portrait
# Processed frame7674 with transformation blurred
# Processed frame5103 with transformation portrait
# Processed frame7 with transformation brightness_adjusted
# Processed frame7679 with transformation blurred
# Processed frame4857 with transformation rotated
# Processed frame777 with transformation blurred
# Processed frame5345 with transformation portrait
# Processed frame7851 with transformation y_reflected
# Processed frame5787 with transformation portrait
# Processed frame5968 with transformation rotated
# Processed frame6248 with transformation rotated
# Processed frame7943 with transformation y_reflected
# Processed frame7551 with transformation brightness_adjusted
# Processed frame6208 with transformation rotated
# Processed frame7 with transformation portrait
# Processed frame5838 with transformation portrait
# Processed frame7632 with transformation brightness_adjustedProcessed frame6354 with transformation rotated
#
# Processed frame637 with transformation rotated
# Processed frame7674 with transformation brightness_adjusted
# Processed frame6807 with transformation rotated
# Processed frame8121 with transformation y_reflected
# Processed frame7851 with transformation blurred
# Processed frame8038 with transformation y_reflected
# Processed frame1037 with transformation y_reflected
# Processed frame777 with transformation brightness_adjusted
# Processed frame7679 with transformation brightness_adjusted
# Processed frame5015 with transformation rotated
# Processed frame7943 with transformation blurred
# Processed frame1161 with transformation y_reflected
# Processed frame5103 with transformation rotated
# Processed frame7551 with transformation portrait
# Processed frame5345 with transformation rotated
# Processed frame1226 with transformation y_reflected
# Processed frame1195 with transformation y_reflected
# Processed frame7632 with transformation portrait
# Processed frame7674 with transformation portrait
# Processed frame1259 with transformation y_reflected
# Processed frame5787 with transformation rotated
# Processed frame7 with transformation rotated
# Processed frame8121 with transformation blurred
# Processed frame7679 with transformation portrait
# Processed frame1037 with transformation blurred
# Processed frame777 with transformation portrait
# Processed frame1161 with transformation blurred
# Processed frame7851 with transformation brightness_adjusted
# Processed frame1359 with transformation y_reflected
# Processed frame5838 with transformation rotated
# Processed frame8038 with transformation blurred
# Processed frame136 with transformation y_reflected
# Processed frame1195 with transformation blurred
# Processed frame7551 with transformation rotated
# Processed frame7943 with transformation brightness_adjusted
# Processed frame1226 with transformation blurred
# Processed frame1557 with transformation y_reflected
# Processed frame1259 with transformation blurred
# Processed frame162 with transformation y_reflected
# Processed frame7632 with transformation rotated
# Processed frame1600 with transformation y_reflected
# Processed frame7674 with transformation rotated
# Processed frame7851 with transformation portrait
# Processed frame1770 with transformation y_reflected
# Processed frame1037 with transformation brightness_adjusted
# Processed frame7943 with transformation portrait
# Processed frame8121 with transformation brightness_adjusted
# Processed frame1161 with transformation brightness_adjusted
# Processed frame1802 with transformation y_reflected
# Processed frame7679 with transformation rotated
# Processed frame1359 with transformation blurred
# Processed frame777 with transformation rotated
# Processed frame136 with transformation blurred
# Processed frame1557 with transformation blurred
# Processed frame1856 with transformation y_reflected
# Processed frame162 with transformation blurred
# Processed frame1195 with transformation brightness_adjusted
# Processed frame1226 with transformation brightness_adjusted
# Processed frame1259 with transformation brightness_adjusted
# Processed frame1939 with transformation y_reflected
# Processed frame8038 with transformation brightness_adjusted
# Processed frame1037 with transformation portrait
# Processed frame1600 with transformation blurred
# Processed frame7851 with transformation rotated
# Processed frame8121 with transformation portrait
# Processed frame1161 with transformation portrait
# Processed frame1944 with transformation y_reflected
# Processed frame1770 with transformation blurred
# Processed frame1802 with transformation blurred
# Processed frame2096 with transformation y_reflected
# Processed frame1856 with transformation blurred
# Processed frame1226 with transformation portrait
# Processed frame1259 with transformation portrait
# Processed frame1195 with transformation portrait
# Processed frame7943 with transformation rotated
# Processed frame1939 with transformation blurred
# Processed frame162 with transformation brightness_adjusted
# Processed frame2177 with transformation y_reflected
# Processed frame136 with transformation brightness_adjusted
# Processed frame1944 with transformation blurred
# Processed frame8038 with transformation portrait
# Processed frame1359 with transformation brightness_adjusted
# Processed frame8121 with transformation rotated
# Processed frame1557 with transformation brightness_adjusted
# Processed frame1161 with transformation rotated
# Processed frame1037 with transformation rotated
# Processed frame2096 with transformation blurred
# Processed frame2207 with transformation y_reflected
# Processed frame1856 with transformation brightness_adjusted
# Processed frame1802 with transformation brightness_adjusted
# Processed frame1226 with transformation rotated
# Processed frame1259 with transformation rotated
# Processed frame1195 with transformation rotated
# Processed frame1600 with transformation brightness_adjusted
# Processed frame162 with transformation portrait
# Processed frame2312 with transformation y_reflected
# Processed frame1939 with transformation brightness_adjusted
# Processed frame2177 with transformation blurred
# Processed frame2225 with transformation y_reflected
# Processed frame2359 with transformation y_reflected
# Processed frame1770 with transformation brightness_adjusted
# Processed frame136 with transformation portrait
# Processed frame2207 with transformation blurred
# Processed frame1359 with transformation portrait
# Processed frame1557 with transformation portrait
# Processed frame2450 with transformation y_reflected
# Processed frame1944 with transformation brightness_adjusted
# Processed frame246 with transformation y_reflected
# Processed frame2440 with transformation y_reflected
# Processed frame2096 with transformation brightness_adjusted
# Processed frame1802 with transformation portrait
# Processed frame1856 with transformation portrait
# Processed frame2312 with transformation blurred
# Processed frame2359 with transformation blurred
# Processed frame1600 with transformation portrait
# Processed frame1939 with transformation portrait
# Processed frame2225 with transformation blurred
# Processed frame8038 with transformation rotated
# Processed frame162 with transformation rotated
# Processed frame1770 with transformation portrait
# Processed frame2177 with transformation brightness_adjusted
# Processed frame2450 with transformation blurred
# Processed frame2440 with transformation blurred
# Processed frame246 with transformation blurred
# Processed frame1944 with transformation portrait
# Processed frame2207 with transformation brightness_adjusted
# Processed frame136 with transformation rotated
# Processed frame2096 with transformation portrait
# Processed frame2312 with transformation brightness_adjusted
# Processed frame2359 with transformation brightness_adjusted
# Processed frame2666 with transformation y_reflected
# Processed frame1856 with transformation rotated
# Processed frame1802 with transformation rotated
# Processed frame2225 with transformation brightness_adjusted
# Processed frame2633 with transformation y_reflected
# Processed frame2177 with transformation portrait
# Processed frame1557 with transformation rotated
# Processed frame1359 with transformation rotated
# Processed frame2207 with transformation portrait
# Processed frame1939 with transformation rotated
# Processed frame2450 with transformation brightness_adjusted
# Processed frame2440 with transformation brightness_adjusted
# Processed frame246 with transformation brightness_adjusted
# Processed frame1944 with transformation rotated
# Processed frame2667 with transformation y_reflected
# Processed frame2312 with transformation portrait
# Processed frame2666 with transformation blurred
# Processed frame1600 with transformation rotated
# Processed frame2359 with transformation portrait
# Processed frame2847 with transformation y_reflected
# Processed frame2870 with transformation y_reflected
# Processed frame2096 with transformation rotated
# Processed frame2225 with transformation portrait
# Processed frame1770 with transformation rotated
# Processed frame2937 with transformation y_reflected
# Processed frame2177 with transformation rotated
# Processed frame2450 with transformation portrait
# Processed frame2633 with transformation blurred
# Processed frame246 with transformation portrait
# Processed frame2440 with transformation portrait
# Processed frame2903 with transformation y_reflected
# Processed frame2909 with transformation y_reflected
# Processed frame2971 with transformation y_reflected
# Processed frame2207 with transformation rotated
# Processed frame2312 with transformation rotated
# Processed frame3005 with transformation y_reflected
# Processed frame2870 with transformation blurred
# Processed frame2847 with transformation blurred
# Processed frame2667 with transformation blurred
# Processed frame2359 with transformation rotated
# Processed frame2988 with transformation y_reflected
# Processed frame2937 with transformation blurred
# Processed frame408 with transformation y_reflected
# Processed frame2666 with transformation brightness_adjusted
# Processed frame3028 with transformation y_reflected
# Processed frame2225 with transformation rotated
# Processed frame2971 with transformation blurred
# Processed frame422 with transformation y_reflected
# Processed frame2909 with transformation blurred
# Processed frame2903 with transformation blurred
# Processed frame246 with transformation rotated
# Processed frame2450 with transformation rotated
# Processed frame3005 with transformation blurred
# Processed frame2440 with transformation rotated
# Processed frame453 with transformation y_reflected
# Processed frame408 with transformation blurred
# Processed frame2870 with transformation brightness_adjusted
# Processed frame2666 with transformation portrait
# Processed frame475 with transformation y_reflected
# Processed frame2633 with transformation brightness_adjusted
# Processed frame2988 with transformation blurred
# Processed frame3028 with transformation blurred
# Processed frame2847 with transformation brightness_adjusted
# Processed frame2937 with transformation brightness_adjusted
# Processed frame58 with transformation y_reflected
# Processed frame580 with transformation y_reflected
# Processed frame422 with transformation blurred
# Processed frame2971 with transformation brightness_adjusted
# Processed frame2667 with transformation brightness_adjusted
# Processed frame616 with transformation y_reflected
# Processed frame632 with transformation y_reflected
# Processed frame2870 with transformation portrait
# Processed frame453 with transformation blurred
# Processed frame475 with transformation blurred
# Processed frame3005 with transformation brightness_adjusted
# Processed frame2847 with transformation portrait
# Processed frame408 with transformation brightness_adjusted
# Processed frame2937 with transformation portrait
# Processed frame580 with transformation blurred
# Processed frame58 with transformation blurred
# Processed frame2633 with transformation portrait
# Processed frame2971 with transformation portrait
# Processed frame2909 with transformation brightness_adjusted
# Processed frame422 with transformation brightness_adjusted
# Processed frame2666 with transformation rotated
# Processed frame2903 with transformation brightness_adjusted
# Processed frame632 with transformation blurred
# Processed frame616 with transformation blurred
# Processed frame3005 with transformation portrait
# Processed frame2667 with transformation portrait
# Processed frame475 with transformation brightness_adjusted
# Processed frame3028 with transformation brightness_adjusted
# Processed frame453 with transformation brightness_adjusted
# Processed frame408 with transformation portrait
# ...
# Processed frame441 with transformation blurred
# Processed frame2715 with transformation rotated
# Processed frame273 with transformation rotated
# Processed frame2712 with transformation rotated
# Processed frame2919 with transformation portrait
# Processed frame3454 with transformation brightness_adjusted
# Processed frame3593 with transformation blurred
# Processed frame3271 with transformation portrait
# Processed frame845 with transformation y_reflected
# Processed frame2732 with transformation rotated
# Processed frame3430 with transformation portrait
# Processed frame3588 with transformation blurred
# Processed frame3139 with transformation portrait
# Processed frame631 with transformation blurred
# Processed frame2928 with transformation portrait
# Processed frame615 with transformation blurred
# Processed frame981 with transformation y_reflected
# Processed frame1000 with transformation y_reflected
# Processed frame894 with transformation y_reflected
# Processed frame397 with transformation brightness_adjusted
# Processed frame1001 with transformation y_reflected
# Processed frame576 with transformation blurred
# Processed frame3528 with transformation brightness_adjusted
# Processed frame441 with transformation brightness_adjusted
# Processed frame3454 with transformation portrait
# Processed frame1016 with transformation y_reflected
# Processed frame845 with transformation blurred
# Processed frame2919 with transformation rotated
# Processed frame3593 with transformation brightness_adjusted
# Processed frame981 with transformation blurred
# Processed frame3271 with transformation rotated
# Processed frame894 with transformation blurred
# Processed frame1000 with transformation blurred
# Processed frame1001 with transformation blurred
# Processed frame3139 with transformation rotated
# Processed frame397 with transformation portrait
# Processed frame631 with transformation brightness_adjusted
# Processed frame3430 with transformation rotated
# Processed frame3588 with transformation brightness_adjusted
# Processed frame1016 with transformation blurred
# Processed frame615 with transformation brightness_adjusted
# Processed frame441 with transformation portrait
# Processed frame3528 with transformation portrait
# Processed frame576 with transformation brightness_adjusted
# Processed frame2928 with transformation rotated
# Processed frame1163 with transformation y_reflected
# Processed frame845 with transformation brightness_adjusted
# Processed frame3593 with transformation portrait
# Processed frame3454 with transformation rotated
# Processed frame1347 with transformation y_reflected
# Processed frame123 with transformation y_reflected
# Processed frame631 with transformation portrait
# Processed frame1441 with transformation y_reflected
# Processed frame981 with transformation brightness_adjusted
# Processed frame615 with transformation portrait
# Processed frame3588 with transformation portrait
# Processed frame397 with transformation rotated
# Processed frame894 with transformation brightness_adjusted
# Processed frame1001 with transformation brightness_adjusted
# Processed frame1163 with transformation blurred
# Processed frame576 with transformation portrait
# Processed frame1492 with transformation y_reflected
# Processed frame1000 with transformation brightness_adjusted
# Processed frame441 with transformation rotated
# Processed frame1692 with transformation y_reflected
# Processed frame1016 with transformation brightness_adjusted
# Processed frame845 with transformation portrait
# Processed frame1347 with transformation blurred
# Processed frame123 with transformation blurred
# Processed frame1441 with transformation blurred
# Processed frame3528 with transformation rotated
# Processed frame981 with transformation portrait
# Processed frame1760 with transformation y_reflected
# Processed frame631 with transformation rotated
# Processed frame3593 with transformation rotated
# Processed frame1001 with transformation portrait
# Processed frame894 with transformation portrait
# Processed frame1000 with transformation portrait
# Processed frame1016 with transformation portrait
# Processed frame1828 with transformation y_reflected
# Processed frame1692 with transformation blurred
# Processed frame1492 with transformation blurred
# Processed frame615 with transformation rotated
# Processed frame3588 with transformation rotated
# Processed frame1163 with transformation brightness_adjusted
# Processed frame576 with transformation rotated
# Processed frame1926 with transformation y_reflected
# Processed frame123 with transformation brightness_adjusted
# Processed frame2062 with transformation y_reflected
# Processed frame1760 with transformation blurred
# Processed frame845 with transformation rotated
# Processed frame2433 with transformation y_reflected
# Processed frame1347 with transformation brightness_adjusted
# Processed frame1441 with transformation brightness_adjusted
# Processed frame1828 with transformation blurred
# Processed frame981 with transformation rotated
# Processed frame2501 with transformation y_reflected
# Processed frame1163 with transformation portrait
# Processed frame2534 with transformation y_reflected
# Processed frame1001 with transformation rotated
# Processed frame1000 with transformation rotated
# Processed frame894 with transformation rotated
# Processed frame1692 with transformation brightness_adjusted
# Processed frame1926 with transformation blurred
# Processed frame1016 with transformation rotated
# Processed frame1492 with transformation brightness_adjusted
# Processed frame123 with transformation portrait
# Processed frame2062 with transformation blurred
# Processed frame1347 with transformation portrait
# Processed frame2566 with transformation y_reflected
# Processed frame2867 with transformation y_reflected
# Processed frame2433 with transformation blurred
# Processed frame2913 with transformation y_reflected
# Processed frame1760 with transformation brightness_adjusted
# Processed frame1441 with transformation portrait
# Processed frame2501 with transformation blurred
# Processed frame3163 with transformation y_reflected
# Processed frame3087 with transformation y_reflected
# Processed frame339 with transformation y_reflected
# Processed frame1828 with transformation brightness_adjusted
# Processed frame2534 with transformation blurred
# Processed frame1692 with transformation portrait
# Processed frame3611 with transformation y_reflected
# Processed frame1163 with transformation rotated
# Processed frame1492 with transformation portrait
# Processed frame2867 with transformation blurred
# Processed frame2566 with transformation blurred
# Processed frame123 with transformation rotated
# Processed frame1760 with transformation portrait
# Processed frame2913 with transformation blurred
# Processed frame2062 with transformation brightness_adjusted
# Processed frame3163 with transformation blurred
# Processed frame3087 with transformation blurred
# Processed frame1347 with transformation rotated
# Processed frame1926 with transformation brightness_adjusted
# Processed frame1828 with transformation portrait
# Processed frame2501 with transformation brightness_adjusted
# Processed frame3611 with transformation blurred
# Processed frame1441 with transformation rotated
# Processed frame3718 with transformation y_reflected
# Processed frame2433 with transformation brightness_adjusted
# Processed frame339 with transformation blurred
# Processed frame2534 with transformation brightness_adjusted
# Processed frame3742 with transformation y_reflected
# Processed frame1692 with transformation rotated
# Processed frame2062 with transformation portrait
# Processed frame3756 with transformation y_reflected
# Processed frame2566 with transformation brightness_adjusted
# Processed frame2913 with transformation brightness_adjusted
# Processed frame1926 with transformation portrait
# Processed frame2501 with transformation portrait
# Processed frame1492 with transformation rotated
# Processed frame376 with transformation y_reflected
# Processed frame1760 with transformation rotated
# Processed frame3087 with transformation brightness_adjusted
# Processed frame2867 with transformation brightness_adjusted
# Processed frame1828 with transformation rotated
# Processed frame3163 with transformation brightness_adjusted
# Processed frame3742 with transformation blurred
# Processed frame2534 with transformation portrait
# Processed frame2433 with transformation portrait
# Processed frame3611 with transformation brightness_adjusted
# Processed frame3718 with transformation blurred
# Processed frame4136 with transformation y_reflected
# Processed frame339 with transformation brightness_adjusted
# Processed frame3756 with transformation blurred
# Processed frame2566 with transformation portrait
# Processed frame2913 with transformation portrait
# Processed frame376 with transformation blurred
# Processed frame4234 with transformation y_reflected
# Processed frame4173 with transformation y_reflected
# Processed frame2062 with transformation rotated
# Processed frame3163 with transformation portrait
# Processed frame4266 with transformation y_reflected
# Processed frame3087 with transformation portrait
# Processed frame2867 with transformation portrait
# Processed frame3611 with transformation portrait
# Processed frame4136 with transformation blurred
# Processed frame2501 with transformation rotated
# Processed frame3742 with transformation brightness_adjusted
# Processed frame3718 with transformation brightness_adjusted
# Processed frame1926 with transformation rotated
# Processed frame455 with transformation y_reflected
# Processed frame4234 with transformation blurred
# Processed frame339 with transformation portrait
# Processed frame2913 with transformation rotated
# Processed frame4266 with transformation blurred
# Processed frame2433 with transformation rotated
# Processed frame2534 with transformation rotated
# Processed frame3756 with transformation brightness_adjusted
# Processed frame4173 with transformation blurred
# Processed frame3163 with transformation rotated
# Processed frame376 with transformation brightness_adjusted
# Processed frame4651 with transformation y_reflected
# Processed frame3742 with transformation portrait
# Processed frame3718 with transformation portrait
# Processed frame3087 with transformation rotated
# Processed frame4136 with transformation brightness_adjusted
# Processed frame3611 with transformation rotated
# Processed frame455 with transformation blurred
# Processed frame4982 with transformation y_reflected
# Processed frame2566 with transformation rotated
# Processed frame4740 with transformation y_reflected
# Processed frame3756 with transformation portrait
# Processed frame4995 with transformation y_reflected
# Processed frame4234 with transformation brightness_adjusted
# Processed frame339 with transformation rotated
# Processed frame5071 with transformation y_reflected
# Processed frame2867 with transformation rotated
# Processed frame5195 with transformation y_reflected
# Processed frame376 with transformation portrait
# Processed frame4266 with transformation brightness_adjusted
# Processed frame4651 with transformation blurred
# Processed frame4136 with transformation portrait
# Processed frame5249 with transformation y_reflected
# Processed frame5394 with transformation y_reflected
# Processed frame4173 with transformation brightness_adjusted
# Processed frame4982 with transformation blurred
# Processed frame3742 with transformation rotated
# Processed frame3718 with transformation rotated
# Processed frame5479 with transformation y_reflected
# Processed frame455 with transformation brightness_adjusted
# Processed frame4234 with transformation portrait
# Processed frame4740 with transformation blurred
# Processed frame4266 with transformation portrait
# Processed frame4995 with transformation blurred
# Processed frame5071 with transformation blurred
# Processed frame5588 with transformation y_reflected
# Processed frame5195 with transformation blurred
# Processed frame5249 with transformation blurred
# Processed frame5760 with transformation y_reflected
# Processed frame5394 with transformation blurred
# Processed frame3756 with transformation rotated
# Processed frame5785 with transformation y_reflected
# Processed frame4651 with transformation brightness_adjusted
# Processed frame376 with transformation rotated
# Processed frame4173 with transformation portrait
# Processed frame5810 with transformation y_reflected
# Processed frame455 with transformation portrait
# Processed frame4982 with transformation brightness_adjusted
# Processed frame4136 with transformation rotated
# Processed frame5479 with transformation blurred
# Processed frame5588 with transformation blurred
# Processed frame4234 with transformation rotated
# Processed frame5785 with transformation blurred
# Processed frame5760 with transformation blurred
# Processed frame4266 with transformation rotated
# Processed frame6192 with transformation y_reflected
# Processed frame4651 with transformation portrait
# Processed frame6302 with transformation y_reflected
# Processed frame4740 with transformation brightness_adjusted
# Processed frame5195 with transformation brightness_adjusted
# Processed frame5810 with transformation blurred
# Processed frame5249 with transformation brightness_adjusted
# Processed frame6367 with transformation y_reflected
# Processed frame5071 with transformation brightness_adjusted
# Processed frame4982 with transformation portrait
# Processed frame4995 with transformation brightness_adjusted
# Processed frame5394 with transformation brightness_adjusted
# Processed frame6442 with transformation y_reflected
# Processed frame5479 with transformation brightness_adjusted
# Processed frame455 with transformation rotated
# Processed frame6302 with transformation blurred
# Processed frame6192 with transformation blurred
# Processed frame4173 with transformation rotated
# Processed frame683 with transformation y_reflected
# Processed frame5195 with transformation portrait
# Processed frame5588 with transformation brightness_adjusted
# Processed frame6367 with transformation blurred
# Processed frame5785 with transformation brightness_adjusted
# Processed frame5249 with transformation portrait
# Processed frame4740 with transformation portrait
# Processed frame5760 with transformation brightness_adjusted
# Processed frame4995 with transformation portrait
# Processed frame5071 with transformation portrait
# Processed frame5810 with transformation brightness_adjusted
# Processed frame5394 with transformation portrait
# Processed frame4651 with transformation rotated
# Processed frame6442 with transformation blurred
# Processed frame5479 with transformation portrait
# Processed frame4982 with transformation rotated
# Processed frame5785 with transformation portrait
# Processed frame6302 with transformation brightness_adjusted
# Processed frame683 with transformation blurred
# Processed frame5588 with transformation portrait
# Processed frame6192 with transformation brightness_adjusted
# Processed frame5195 with transformation rotated
# Processed frame5810 with transformation portrait
# Processed frame5760 with transformation portrait
# Processed frame6367 with transformation brightness_adjusted
# Processed frame5249 with transformation rotated
# Processed frame4740 with transformation rotated
# Processed frame6302 with transformation portrait
# Processed frame6442 with transformation brightness_adjusted
# Processed frame5071 with transformation rotated
# Processed frame4995 with transformation rotated
# Processed frame6192 with transformation portrait
# Processed frame6367 with transformation portrait
# Processed frame5394 with transformation rotated
# Processed frame5479 with transformation rotated
# Processed frame683 with transformation brightness_adjustedProcessed frame5785 with transformation rotated
#
# Processed frame5810 with transformation rotated
# Processed frame5588 with transformation rotated
# Processed frame6442 with transformation portrait
# Processed frame5760 with transformation rotated
# Processed frame6302 with transformation rotated
# Processed frame6192 with transformation rotated
# Processed frame6367 with transformation rotated
# Processed frame683 with transformation portrait
# Processed frame6442 with transformation rotated
# Processed frame683 with transformation rotated
# All directories processed!

# %% [markdown]
# # resize to 510,300

# %%
import os
from PIL import Image
import xml.etree.ElementTree as ET
from concurrent.futures import ThreadPoolExecutor, as_completed

def resize_image(image_path, output_path, target_size):
    try:
        with Image.open(image_path) as img:
            original_size = img.size
            img = img.resize(target_size, Image.LANCZOS)
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            img.save(output_path)
        print(f"Resized image saved to {output_path}")
        return original_size
    except Exception as e:
        print(f"Error resizing image {image_path}: {e}")
        return None

def resize_xml(xml_path, output_path, original_size, target_size):
    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()
        
        for size in root.findall('size'):
            size.find('width').text = str(target_size[0])
            size.find('height').text = str(target_size[1])

        scale_x = target_size[0] / original_size[0]
        scale_y = target_size[1] / original_size[1]

        for obj in root.findall('object'):
            for box in obj.findall('bndbox'):
                box.find('xmin').text = str(int(float(box.find('xmin').text) * scale_x))
                box.find('ymin').text = str(int(float(box.find('ymin').text) * scale_y))
                box.find('xmax').text = str(int(float(box.find('xmax').text) * scale_x))
                box.find('ymax').text = str(int(float(box.find('ymax').text) * scale_y))

        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        tree.write(output_path)
        print(f"Resized XML saved to {output_path}")
    except Exception as e:
        print(f"Error resizing XML {xml_path}: {e}")

def process_files(root, files, source_base_dir, output_base_dir, target_size):
    for file in files:
        if file.lower().endswith(('jpg', 'jpeg', 'png')):
            image_path = os.path.join(root, file)
            relative_path = os.path.relpath(image_path, source_base_dir)
            output_image_path = os.path.join(output_base_dir, relative_path)

            xml_path = image_path.replace(os.path.splitext(file)[1], '.xml')
            output_xml_path = output_image_path.replace(os.path.splitext(file)[1], '.xml')

            original_size = resize_image(image_path, output_image_path, target_size)
            if original_size and os.path.exists(xml_path):
                resize_xml(xml_path, output_xml_path, original_size, target_size)

def resize_files_in_directory(source_base_dir, output_base_dir, target_size=(510,510)):
    with ThreadPoolExecutor() as executor:
        futures = []
        for root, dirs, files in os.walk(source_base_dir):
            futures.append(executor.submit(process_files, root, files, source_base_dir, output_base_dir, target_size))

        for future in as_completed(futures):
            try:
                future.result()
            except Exception as e:
                print(f"Error processing files: {e}")

    print("All files processed!")

# Run the resizing process
source_base_dir = r"C:\Users\ybr5070\Desktop\split"  # Replace with the path to your new sampled directory
output_base_dir = r"C:\Users\ybr5070\Desktop\split_resized"  # Replace with the path to your resized output directory
resize_files_in_directory(source_base_dir, output_base_dir)
# Out:
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame10267.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame10012.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame10267.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1037.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1114.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1162.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1065.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1015.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame10012.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1055.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1162.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1031.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10084.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1065.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1037.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1015.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1031.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1093.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1052.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1087.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame10023.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1055.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1019.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10084.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1114.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10012.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1217.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1087.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame10023.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame1011.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1145.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1052.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1093.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame125.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1019.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1217.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1096.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1121.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame1011.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame125.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10012.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1145.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame10336.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1121.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame10147.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1096.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1064.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1060.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1191.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame10334.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame10147.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1064.xmlResized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1191.xml
#
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10244.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1161.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1044.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame10334.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1220.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1229.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1161.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1392.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1158.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1374.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame1395.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1044.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10244.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10184.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1020.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1028.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1126.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1158.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1374.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame1395.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame10336.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10322.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1229.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1020.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1116.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1028.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10184.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1060.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1392.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1220.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1158.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1220.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1195.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1220.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame10544.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1180.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1079.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame140.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10317.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1180.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1126.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame15.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1116.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1195.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10322.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10317.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10270.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1155.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1158.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame15.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1163.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1182.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1079.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame134.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1155.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1085.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1163.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1288.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1182.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1364.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1288.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame140.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1152.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1085.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame10544.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1501.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10270.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1364.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1206.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame1408.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1153.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame134.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1033.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame1408.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1206.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10621.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1153.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1354.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10549.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame1724.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10621.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1157.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1162.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame11.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame122.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10549.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1152.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1356.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1501.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame1724.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1354.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1157.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1033.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1162.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1226.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame11.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame122.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1226.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1465.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10422.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame112.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1356.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1197.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1478.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1508.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1465.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1370.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1197.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1478.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame112.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10873.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10422.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1508.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1370.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame1671.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1233.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1434.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1545.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1316.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame1671.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1233.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1545.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1036.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1230.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1330.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1468.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1251.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1036.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1259.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1468.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1259.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1397.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1251.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame180.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1262.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1439.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1101.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame153.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10807.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame10873.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1397.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1323.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1101.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1217.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1477.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1077.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1230.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame180.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1330.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame136.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame1963.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame153.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1077.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1323.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1143.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1778.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame1963.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame136.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1276.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1585.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1143.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1439.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1778.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1477.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1585.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1114.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1276.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1592.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame134.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11141.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1538.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame1898.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10854.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1538.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1114.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1217.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1592.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1237.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame134.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11141.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1741.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame115.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame1898.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame10854.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1237.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1741.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame115.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1418.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1621.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2097.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1791.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10807.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1621.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1278.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2097.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1791.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1434.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1359.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11276.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1316.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1262.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1616.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame2041.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame140.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1998.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1616.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1359.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1555.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame140.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame1998.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1144.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1194.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1367.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1206.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1543.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1568.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1194.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1278.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1921.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2284.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame165.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1287.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1543.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1287.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1568.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2284.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1278.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame165.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1524.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1243.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10860.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1555.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1524.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1243.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1278.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10860.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2040.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1206.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1206.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame1921.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1870.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2040.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1367.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1351.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1206.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1683.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1638.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1144.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1351.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1683.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame126.jpgResized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame1870.xml
#
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame136.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame231.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame187.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1638.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame126.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame2343.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1569.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame2343.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame141.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1569.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1736.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1391.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1718.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame141.xmlResized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame2190.jpg
#
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1402.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame231.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame187.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1226.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame2190.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1402.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1860.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1418.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1718.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1226.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1700.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2095.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10878.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1700.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10878.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1704.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame1860.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1736.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1704.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2095.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame2041.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1322.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1467.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1507.jpgResized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame136.xml
#
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame123.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1305.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1999.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame123.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1467.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10922.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11276.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1305.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame1999.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1771.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1342.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1455.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame10922.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1516.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1771.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1322.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1455.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1342.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1516.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame2480.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame200.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame200.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1457.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame11007.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1254.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11330.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1457.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame148.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1254.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1374.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2427.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1557.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1557.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2427.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2545.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11330.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1391.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame162.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame2190.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame2185.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame178.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1331.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame179.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1268.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame162.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1395.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame2185.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame2190.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2545.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1268.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame2480.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame179.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame151.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame11007.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2465.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame148.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame151.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1395.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame2051.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame2051.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame2249.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame2361.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11624.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2465.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1301.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1331.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1507.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame11127.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1492.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame178.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1809.jpgResized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1219.jpg
#
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1600.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame2593.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_070_V2_PS2_fixed\frame11624.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1445.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2573.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame2593.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1374.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame11127.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame1600.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1473.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1800.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1685.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame2404.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_093_V2_PS2_fixed\frame2573.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame1219.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_089_V2_PS4_fixed\frame1445.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame2249.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_038_V3_PS1_fixed\frame1685.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V4_PS1_fixed\frame1473.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_020_V4_PS2_fixed\frame1800.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_023_V4_PS1_fixed\frame1492.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame2404.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_127_V3_PS2_fixed\frame1809.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame2240.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1423.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1809.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1932.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame1809.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1423.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_006_V4_PS1_fixed\frame162.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_005_V4_PS2_fixed\frame2606.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1594.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame126.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1594.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame11242.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1588.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame2014.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame2571.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1509.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_026_V3_PS3_fixed\frame1382.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2532.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_073_V5_PS2_fixed\frame2014.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_017_V5_PS3_fixed\frame11242.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_030_V4_PS2_fixed\frame2361.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_090_V5_PS1_fixed\frame1588.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_069_V2_PS1_fixed\frame1509.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_072_V4_PS2_fixed\frame1932.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_056_V5_PS3_fixed\frame2240.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V2_PS1_fixed\frame2532.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_035_V2_PS4_fixed\frame1623.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\test\R01_030_V3_PS4_fixed\frame2571.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_001_V3_PS4_fixed\frame126.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_031_V4_PS4_fixed\frame1301.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train\R01_009_V4_PS4_fixed\frame2780.jpg
# ...
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_blurred.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_blurred.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_brightness_adjusted.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_portrait.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_brightness_adjusted.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_portrait.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_rotated.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_rotated.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame631_y_reflected.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_rotated.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_y_reflected.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame724_y_reflected.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_rotated.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame844_y_reflected.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_blurred.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_blurred.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_blurred.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_blurred.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6302_y_reflected.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_blurred.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_portrait.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_portrait.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_brightness_adjusted.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_portrait.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_rotated.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_portrait.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_rotated.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_portrait.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_y_reflected.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_y_reflected.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame859_y_reflected.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame845_y_reflected.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame865_y_reflected.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_blurred.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_blurred.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_blurred.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_blurred.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6367_y_reflected.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_brightness_adjusted.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_brightness_adjusted.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_blurred.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_portrait.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_portrait.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_rotated.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_rotated.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_rotated.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_rotated.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_y_reflected.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame894_y_reflected.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V3_PS2 _fixed\frame894_y_reflected.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_rotated.jpg
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_rotated.xml
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_127_V4_PS1_fixed\frame980_y_reflected.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_blurred.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame6442_y_reflected.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_blurred.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_blurred.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_brightness_adjusted.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_brightness_adjusted.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_portrait.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_portrait.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_128_V5_PS4_fixed\frame981_y_reflected.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_rotated.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_rotated.xml
# Resized image saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_y_reflected.jpg
# Resized XML saved to C:\Users\ybr5070\Desktop\split_resized\train_trans\R01_133_V2_PS3_fixed\frame683_y_reflected.xml
# All files processed!

# %% [markdown]
# # convert xml to yolo files
# remember to add classes.txt everywhere

# %%
import os
import shutil
import concurrent.futures
import xml.etree.ElementTree as ET

def convert_xml_to_yolo(xml_file, dest_dir):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    size = root.find('size')
    width = int(size.find('width').text)
    height = int(size.find('height').text)

    yolo_annotations = []

    for obj in root.findall('object'):
        name = obj.find('name').text
        if name == 'child_face':  # Assuming class 'child_face' has an ID of 15
            class_id = 15
        else:
            continue

        xmlbox = obj.find('bndbox')
        xmin = int(xmlbox.find('xmin').text)
        xmax = int(xmlbox.find('xmax').text)
        ymin = int(xmlbox.find('ymin').text)
        ymax = int(xmlbox.find('ymax').text)

        x_center = (xmin + xmax) / 2.0 / width
        y_center = (ymin + ymax) / 2.0 / height
        w = (xmax - xmin) / float(width)
        h = (ymax - ymin) / float(height)

        yolo_annotations.append(f"{class_id} {x_center} {y_center} {w} {h}")

    yolo_file = os.path.join(dest_dir, os.path.splitext(os.path.basename(xml_file))[0] + '.txt')
    ensure_directory_exists(dest_dir)
    with open(yolo_file, 'w') as f:
        f.write("\n".join(yolo_annotations))

def ensure_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def move_file(src_file, dest_dir):
    ensure_directory_exists(dest_dir)
    shutil.copy(src_file, os.path.join(dest_dir, os.path.basename(src_file)))

def process_annotations(src_dir, dest_txt_dir):
    xml_tasks = []

    for root, dirs, files in os.walk(src_dir):
        for file in files:
            if file.endswith(".xml"):
                src_file = os.path.join(root, file)
                dest = os.path.join(dest_txt_dir, os.path.relpath(root, src_dir))
                xml_tasks.append((src_file, dest))
                convert_xml_to_yolo(src_file, dest)

    return xml_tasks

base_dir = r"C:\Users\ybr5070\Desktop\split_resized"
new_base_dir = r"C:\Users\ybr5070\Desktop\yolo_split\labels"
categories = ["train", "train_trans", "val", "test"]

all_txt_tasks = []

# Process XML tasks (conversion and move)
for category in categories:
    src_dir = os.path.join(base_dir, category)
    dest_txt_dir = os.path.join(new_base_dir, category)
    process_annotations(src_dir, dest_txt_dir)

# %% [markdown]
# # move images

# %%
import os
import shutil
import concurrent.futures

def ensure_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def move_file(src_file, dest_dir):
    ensure_directory_exists(dest_dir)
    shutil.copy(src_file, os.path.join(dest_dir, os.path.basename(src_file)))

def process_images(src_dir, dest_img_dir):
    img_tasks = []

    for root, dirs, files in os.walk(src_dir):
        for file in files:
            if file.endswith(".jpg"):  # Ensure it only processes .jpg files
                src_file = os.path.join(root, file)
                dest = os.path.join(dest_img_dir, os.path.relpath(root, src_dir))
                img_tasks.append((src_file, dest))

    return img_tasks

def move_files_in_parallel(tasks):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        executor.map(lambda p: move_file(*p), tasks)

base_dir = r"C:\Users\ybr5070\Desktop\split_resized"
new_base_dir = r"C:\Users\ybr5070\Desktop\yolo_split\images"
categories = ["train", "train_trans", "val", "test"]

all_img_tasks = []

# Process image tasks
for category in categories:
    src_dir = os.path.join(base_dir, category)
    dest_img_dir = os.path.join(new_base_dir, category)
    img_tasks = process_images(src_dir, dest_img_dir)
    all_img_tasks.extend(img_tasks)

# Ensure all directories are created before copying files
for task in all_img_tasks:
    _, dest_dir = task
    ensure_directory_exists(dest_dir)

# Move image files in parallel
move_files_in_parallel(all_img_tasks)

# %% [markdown]
# # merge bucket by bucket

# %%
import os
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed

# Define the base paths
base_path = r"C:\Users\ybr5070\Desktop\yolo_split"
output_path = r"C:\Users\ybr5070\Desktop\yolo_merged_1"

# Ensure the output directories exist
os.makedirs(os.path.join(output_path, "images", "train"), exist_ok=True)
os.makedirs(os.path.join(output_path, "images", "val"), exist_ok=True)
os.makedirs(os.path.join(output_path, "images", "test"), exist_ok=True)
os.makedirs(os.path.join(output_path, "images", "trans"), exist_ok=True)

os.makedirs(os.path.join(output_path, "labels", "train"), exist_ok=True)
os.makedirs(os.path.join(output_path, "labels", "val"), exist_ok=True)
os.makedirs(os.path.join(output_path, "labels", "test"), exist_ok=True)
os.makedirs(os.path.join(output_path, "labels", "trans"), exist_ok=True)

def copy_and_rename_file(image_file, label_file, dest_image_dir, dest_label_dir, index):
    # Copy image and label files to the destination directory with new index
    shutil.copy(image_file, os.path.join(dest_image_dir, f"{index}.jpg"))
    shutil.copy(label_file, os.path.join(dest_label_dir, f"{index}.txt"))

def process_directory(source_image_dir, source_label_dir, dest_image_dir, dest_label_dir, start_index):
    index = start_index
    tasks = []
    with ThreadPoolExecutor(max_workers=8) as executor:
        for root, _, files in os.walk(source_image_dir):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    image_file = os.path.join(root, file)
                    label_file = os.path.join(root.replace('images', 'labels'), file.replace('.jpg', '.txt').replace('.png', '.txt'))
                    tasks.append(executor.submit(copy_and_rename_file, image_file, label_file, dest_image_dir, dest_label_dir, index))
                    index += 1
        for task in as_completed(tasks):
            task.result()
    return index

# Process each set
index_train = process_directory(os.path.join(base_path, "images", "train"), os.path.join(base_path, "labels", "train"), os.path.join(output_path, "images", "train"), os.path.join(output_path, "labels", "train"), 0)
index_trans = process_directory(os.path.join(base_path, "images", "trans"), os.path.join(base_path, "labels", "trans"), os.path.join(output_path, "images", "trans"), os.path.join(output_path, "labels", "trans"), 0)
index_val = process_directory(os.path.join(base_path, "images", "val"), os.path.join(base_path, "labels", "val"), os.path.join(output_path, "images", "val"), os.path.join(output_path, "labels", "val"), 0)
index_test = process_directory(os.path.join(base_path, "images", "test"), os.path.join(base_path, "labels", "test"), os.path.join(output_path, "images", "test"), os.path.join(output_path, "labels", "test"), 0)

# Add train_trans to train after trans
index_train_trans = process_directory(os.path.join(base_path, "images", "train_trans"), os.path.join(base_path, "labels", "train_trans"), os.path.join(output_path, "images", "train"), os.path.join(output_path, "labels", "train"), index_train)

print("Files have been successfully renamed and merged.")
# Out:
# Files have been successfully renamed and merged.

# %% [markdown]
# # cleanup classes and annotations

# %%
import os

# Mapping of class names to class IDs
class_name_to_id = {
    'dog': 0,
    'person': 1,
    'cat': 2,
    'tv': 3,
    'car': 4,
    'meatballs': 5,
    'marinara sauce': 6,
    'tomato soup': 7,
    'chicken noodle soup': 8,
    'french onion soup': 9,
    'chicken breast': 10,
    'ribs': 11,
    'pulled pork': 12,
    'hamburger': 13,
    'cavity': 14,
    'child_face': 15
}

def convert_annotation(file_path, target_class_id, new_class_id):
    """
    Convert annotations for target_class_id to new_class_id and remove others.

    :param file_path: Path to the annotation file
    :param target_class_id: The original class ID for child_face
    :param new_class_id: The new class ID to assign (0)
    """
    try:
        with open(file_path, 'r') as f:
            lines = f.readlines()

        with open(file_path, 'w') as f:
            for line in lines:
                parts = line.split()
                try:
                    class_id = int(parts[0])
                except ValueError:
                    class_id = class_name_to_id[parts[0]]

                if class_id == target_class_id:
                    parts[0] = str(new_class_id)
                    f.write(" ".join(parts) + '\n')
                elif class_id == new_class_id:
                    f.write(" ".join(parts) + '\n')
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

def process_split(split_dir, target_class_id, new_class_id):
    """
    Process all annotation files in the given split directory.

    :param split_dir: Directory containing the annotation files
    :param target_class_id: The original class ID for child_face
    :param new_class_id: The new class ID to assign (0)
    """
    files = [os.path.join(split_dir, f) for f in os.listdir(split_dir) if os.path.isfile(os.path.join(split_dir, f))]
    for file_path in files:
        convert_annotation(file_path, target_class_id, new_class_id)

def main():
    label_dir = r"C:\Users\ybr5070\Desktop\yolo_merged_1\labels"   # Update with your labels directory path
    target_class_name = 'child_face'  # The original class name for child_face
    new_class_id = 0  # The new class ID for child_face
    target_class_id = class_name_to_id[target_class_name]

    for split in ["train", "test", "val"]:
        split_dir = os.path.join(label_dir, split)
        process_split(split_dir, target_class_id, new_class_id)

if __name__ == "__main__":
    main()
# Out:
# Error processing file C:\Users\ybr5070\Desktop\yolo_merged_1\labels\train\classes.txt: 'marinara'
# Error processing file C:\Users\ybr5070\Desktop\yolo_merged_1\labels\test\classes.txt: 'marinara'
# Error processing file C:\Users\ybr5070\Desktop\yolo_merged_1\labels\val\classes.txt: 'marinara'

# %% [markdown]
# # check labels

# %%
import os

def check_labels(split_dir):
    """
    Check if all annotations have the label 0 in the given split directory.

    :param split_dir: Directory containing the annotation files
    :return: List of files with incorrect labels
    """
    incorrect_files = []
    files = [os.path.join(split_dir, f) for f in os.listdir(split_dir) if os.path.isfile(os.path.join(split_dir, f))]
    for file_path in files:
        with open(file_path, 'r') as f:
            lines = f.readlines()
            for line in lines:
                parts = line.split()
                class_id = int(parts[0])
                if class_id != 0:
                    incorrect_files.append(file_path)
                    break
    return incorrect_files

def main():
    label_dir = r"C:\Users\ybr5070\Desktop\yolo_merged_1\labels"  # Update with your labels directory path
    incorrect_files = []
    
    for split in ["train", "test", "val"]:
        split_dir = os.path.join(label_dir, split)
        incorrect_files.extend(check_labels(split_dir))
    
    if incorrect_files:
        print("The following files contain labels other than 0:")
        for file in incorrect_files:
            print(file)
    else:
        print("All annotations have the label 0.")

if __name__ == "__main__":
    main()
# Out:
# All annotations have the label 0.
