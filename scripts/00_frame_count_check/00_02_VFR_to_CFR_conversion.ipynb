# %% [markdown]
# ## Video variable frame rate to Constant frame rate 30FPS

# %%
import os
import subprocess
import psutil

def ensure_directory_exists(folder_path):
    """Ensure that a directory exists, creating it if necessary."""
    try:
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        print(f"Directory created: {folder_path}")
        return True
    except Exception as e:
        print(f"Failed to create directory {folder_path}: {e}")
        return False

def get_optimal_threads(max_threads):
    """Determine the optimal number of threads based on CPU usage."""
    cpu_usage = psutil.cpu_percent(interval=1)
    if cpu_usage < 50:
        return max_threads
    elif cpu_usage < 75:
        return max(1, max_threads // 2)
    else:
        return max(1, max_threads // 4)

def convert_video_to_cfr(video_path, ffmpeg_path, output_folder, output_video_fps, max_threads):
    """Convert video from VFR to CFR without audio."""
    original_basename = os.path.splitext(os.path.basename(video_path))[0]
    output_video_name = f"{original_basename}_fixed.mp4"
    output_video_path = os.path.join(output_folder, output_video_name)

    if os.path.exists(output_video_path):
        print(f"Skipping {video_path} as output video already exists.")
        return

    if not ensure_directory_exists(output_folder):
        return

    print(f"Starting conversion for {video_path}")
    threads = get_optimal_threads(max_threads)
    print(f"Temporary video being created: {output_video_path}")
    command = [
        ffmpeg_path, '-loglevel', 'verbose', '-i', video_path, '-r', str(output_video_fps),
        '-b:v 2M', 'h264_v4l2m2m', '-threads', str(threads), '-an', output_video_path
    ]

    try:
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        if result.returncode != 0:
            print("FFmpeg failed with the following output:")
            print(result.stdout)
            print(result.stderr)
        else:
            print("Successfully converted:")
            print(result.stdout)
            print(f"{video_path} to {output_video_path}")
    except Exception as e:
        print(f"An error occurred while processing {video_path}: {str(e)}")

def process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads):
    """Process all videos in a directory."""
    if not ensure_directory_exists(output_directory):
        return

    video_files = [f for f in os.listdir(input_directory) if f.endswith(('.avi', '.mp4', '.mov'))]
    for video_file in video_files:
        video_path = os.path.join(input_directory, video_file)
        convert_video_to_cfr(video_path, ffmpeg_path, output_directory, output_fps, max_threads)

# Configuration for converting video files
ffmpeg_path = "/swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg"
input_directory = "/storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/"
output_directory = "/storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/"
output_fps = 30
max_threads = 6

process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads)
# Out:
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_001_V4_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_001_V4_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_002_V2_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_002_V2_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_003_V5_PS2.mp4
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_003_V5_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_004_V2_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_004_V2_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_005_V4_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_005_V4_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_006_V5_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_006_V5_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_007_V4_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_007_V4_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_009_V2_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_009_V2_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_011_V5_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_011_V5_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_017_V4_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_017_V4_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_018_V2_PS2.avi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 77
#      74 output_fps = 30
#      75 max_threads = 6
# ---> 77 process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads)
#
# Cell In[8], line 68, in process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads)
#      66 for video_file in video_files:
#      67     video_path = os.path.join(input_directory, video_file)
# ---> 68     convert_video_to_cfr(video_path, ffmpeg_path, output_directory, output_fps, max_threads)
#
# Cell In[8], line 40, in convert_video_to_cfr(video_path, ffmpeg_path, output_folder, output_video_fps, max_threads)
#      37     return
#      39 print(f"Starting conversion for {video_path}")
# ---> 40 threads = get_optimal_threads(max_threads)
#      41 print(f"Temporary video being created: {output_video_path}")
#      42 command = [
#      43     ffmpeg_path, '-loglevel', 'verbose', '-i', video_path, '-r', str(output_video_fps),
#      44     '-c:v', 'h264_v4l2m2m', '-threads', str(threads), '-an', output_video_path
#      45 ]
#
# Cell In[8], line 18, in get_optimal_threads(max_threads)
#      16 def get_optimal_threads(max_threads):
#      17     """Determine the optimal number of threads based on CPU usage."""
# ---> 18     cpu_usage = psutil.cpu_percent(interval=1)
#      19     if cpu_usage < 50:
#      20         return max_threads
#
# File ~/.conda/envs/hb_env/lib/python3.12/site-packages/psutil/__init__.py:1747, in cpu_percent(interval, percpu)
#    1745 if blocking:
#    1746     t1 = cpu_times()
# -> 1747     time.sleep(interval)
#    1748 else:
#    1749     t1 = _last_cpu_times
#
# KeyboardInterrupt:

# %%
import os
import subprocess
import psutil

def ensure_directory_exists(folder_path):
    """Ensure that a directory exists, creating it if necessary."""
    try:
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        print(f"Directory created: {folder_path}")
        return True
    except Exception as e:
        print(f"Failed to create directory {folder_path}: {e}")
        return False

def get_optimal_threads(max_threads):
    """Determine the optimal number of threads based on CPU usage."""
    cpu_usage = psutil.cpu_percent(interval=1)
    if cpu_usage < 50:
        return max_threads
    elif cpu_usage < 75:
        return max(1, max_threads // 2)
    else:
        return max(1, max_threads // 4)

def convert_video_to_cfr(video_path, ffmpeg_path, output_folder, output_video_fps, max_threads):
    """Convert video from VFR to CFR without audio."""
    original_basename = os.path.splitext(os.path.basename(video_path))[0]
    output_video_name = f"{original_basename}_fixed.mp4"
    output_video_path = os.path.join(output_folder, output_video_name)

    if os.path.exists(output_video_path):
        print(f"Skipping {video_path} as output video already exists.")
        return

    if not ensure_directory_exists(output_folder):
        return

    print(f"Starting conversion for {video_path}")
    threads = get_optimal_threads(max_threads)
    print(f"Temporary video being created: {output_video_path}")
    command = [
        ffmpeg_path, '-loglevel', 'verbose', '-i', video_path, '-r', str(output_video_fps),
        '-c:v', 'h264_v4l2m2m', '-threads', str(threads), '-an', output_video_path
    ]

    print("Executing FFmpeg command:")
    print(" ".join(command))

    try:
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        if result.returncode != 0:
            print("FFmpeg failed with the following output:")
            print(result.stdout)
            print(result.stderr)
        else:
            print("Successfully converted:")
            print(result.stdout)
            print(f"{video_path} to {output_video_path}")
    except Exception as e:
        print(f"An error occurred while processing {video_path}: {str(e)}")

def process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads):
    """Process all videos in a directory."""
    if not ensure_directory_exists(output_directory):
        return

    video_files = [f for f in os.listdir(input_directory) if f.endswith(('.avi', '.mp4', '.mov'))]
    for video_file in video_files:
        video_path = os.path.join(input_directory, video_file)
        convert_video_to_cfr(video_path, ffmpeg_path, output_directory, output_fps, max_threads)

# Configuration for converting video files
ffmpeg_path = "/swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg"
input_directory = "/storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/"
output_directory = "/storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/"
output_fps = 30
max_threads = 6

process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads)
# Out:
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_001_V4_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_001_V4_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_001_V4_PS2.avi -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_001_V4_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_002_V2_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_002_V2_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_002_V2_PS2.avi -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_002_V2_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_003_V5_PS2.mp4
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_003_V5_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_003_V5_PS2.mp4 -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_003_V5_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_004_V2_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_004_V2_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_004_V2_PS2.avi -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_004_V2_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_005_V4_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_005_V4_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_005_V4_PS2.avi -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_005_V4_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_006_V5_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_006_V5_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_006_V5_PS2.avi -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_006_V5_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_007_V4_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_007_V4_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_007_V4_PS2.avi -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_007_V4_PS2_fixed.mp4
# FFmpeg failed with the following output:
#
#
# Directory created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/
# Starting conversion for /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_009_V2_PS2.avi
# Temporary video being created: /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_009_V2_PS2_fixed.mp4
# Executing FFmpeg command:
# /swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg -loglevel verbose -i /storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/R01_009_V2_PS2.avi -r 30 -c:v h264_v4l2m2m -threads 6 -an /storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/R01_009_V2_PS2_fixed.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 80
#      77 output_fps = 30
#      78 max_threads = 6
# ---> 80 process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads)
#
# Cell In[9], line 71, in process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads)
#      69 for video_file in video_files:
#      70     video_path = os.path.join(input_directory, video_file)
# ---> 71     convert_video_to_cfr(video_path, ffmpeg_path, output_directory, output_fps, max_threads)
#
# Cell In[9], line 51, in convert_video_to_cfr(video_path, ffmpeg_path, output_folder, output_video_fps, max_threads)
#      48 print(" ".join(command))
#      50 try:
# ---> 51     result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
#      52     if result.returncode != 0:
#      53         print("FFmpeg failed with the following output:")
#
# File ~/.conda/envs/hb_env/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/.conda/envs/hb_env/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/.conda/envs/hb_env/lib/python3.12/subprocess.py:2113, in Popen._communicate(self, input, endtime, orig_timeout)
#    2106     self._check_timeout(endtime, orig_timeout,
#    2107                         stdout, stderr,
#    2108                         skip_check_and_raise=True)
#    2109     raise RuntimeError(  # Impossible :)
#    2110         '_check_timeout(..., skip_check_and_raise=True) '
#    2111         'failed to raise TimeoutExpired.')
# -> 2113 ready = selector.select(timeout)
#    2114 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2116 # XXX Rewrite these to use non-blocking I/O on the file
#    2117 # objects; they are no longer using C stdio!
#
# File ~/.conda/envs/hb_env/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
!"/swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg" -codecs | grep h264

# %%
import os
import subprocess
import psutil

def ensure_directory_exists(folder_path):
    """Ensure that a directory exists, creating it if necessary."""
    try:
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        print(f"Directory created: {folder_path}")
        return True
    except Exception as e:
        print(f"Failed to create directory {folder_path}: {e}")
        return False

def get_optimal_threads(max_threads):
    """Determine the optimal number of threads based on CPU usage."""
    cpu_usage = psutil.cpu_percent(interval=1)
    if cpu_usage < 50:
        return max_threads
    elif cpu_usage < 75:
        return max(1, max_threads // 2)
    else:
        return max(1, max_threads // 4)

def convert_video_to_cfr(video_path, ffmpeg_path, output_folder, output_video_fps, max_threads):
    """Convert video from VFR to CFR without audio."""
    original_basename = os.path.splitext(os.path.basename(video_path))[0]
    output_video_name = f"{original_basename}_fixed.mp4"
    output_video_path = os.path.join(output_folder, output_video_name)

    if os.path.exists(output_video_path):
        print(f"Skipping {video_path} as output video already exists.")
        return

    if not ensure_directory_exists(output_folder):
        return

    print(f"Starting conversion for {video_path}")
    threads = get_optimal_threads(max_threads)
    print(f"Using {threads} threads for conversion.")
    command = [
        ffmpeg_path, '-loglevel', 'verbose', '-i', video_path, '-r', str(output_video_fps),
        '-c:v', 'mpeg4', '-threads', str(threads), '-an', output_video_path
    ]

    try:
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        if result.returncode != 0:
            print("FFmpeg failed with the following output:")
            print(result.stdout)
            print(result.stderr)
        else:
            print("Successfully converted:")
            print(f"{video_path} to {output_video_path}")
    except Exception as e:
        print(f"An error occurred while processing {video_path}: {str(e)}")

def process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads):
    """Process all videos in a directory."""
    if not ensure_directory_exists(output_directory):
        return

    video_files = [f for f in os.listdir(input_directory) if f.endswith(('.avi', '.mp4', '.mov'))]
    for video_file in video_files:
        video_path = os.path.join(input_directory, video_file)
        convert_video_to_cfr(video_path, ffmpeg_path, output_directory, output_fps, max_threads)

# Configuration for converting video files
ffmpeg_path = "/swst/apps/ffmpeg/4.3.2_gcc-8.5.0/bin/ffmpeg"
input_directory = "/storage/group/klk37/default/homebytes/video/fbs/PS_vids_original/PortionSize2/"
output_directory = "/storage/group/klk37/default/homebytes/video/fbs/PS2_vids_fixed_1/"
output_fps = 30
max_threads = 16

process_all_videos(input_directory, ffmpeg_path, output_directory, output_fps, max_threads)
